# %%
# Imports needed to complete this assignment
import pandas as pd
import numpy as np
import scipy
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
banking = pd.read_csv('banking_churn.csv')

# %%
banking.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0
# 2        113931.57       1
# 3         93826.63       0
# ...

# %%
banking.dtypes
# Out:
# RowNumber            int64
# CustomerId           int64
# Surname             object
# CreditScore          int64
# Geography           object
# Gender              object
# Age                  int64
# Tenure               int64
# Balance            float64
# NumOfProducts        int64
# HasCrCard            int64
# IsActiveMember       int64
# EstimatedSalary    float64
# Exited               int64
# dtype: object

# %%
for col in banking.columns:
    if banking[col].dtype != 'object':
        print(f'{col}: {scipy.stats.skew(banking[col])}')
# Out:
# RowNumber: 0.0
# CustomerId: 0.001148973521486491
# CreditScore: -0.07159586676212397
# Age: 1.0111685586628079
# Tenure: 0.010989809189781041
# Balance: -0.14108754375291138
# NumOfProducts: 0.745456048438949
# HasCrCard: -0.9016763178640548
# IsActiveMember: -0.06042756246298516
# EstimatedSalary: 0.0020850448448748848
# Exited: 1.4713899141398699

# %%
banking.info
# Out:
# <bound method DataFrame.info of       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 0             1    15634602   Hargrave          619    France  Female   42
# 1             2    15647311       Hill          608     Spain  Female   41
# 2             3    15619304       Onio          502    France  Female   42
# 3             4    15701354       Boni          699    France  Female   39
# 4             5    15737888   Mitchell          850     Spain  Female   43
# ...         ...         ...        ...          ...       ...     ...  ...
# 9995       9996    15606229   Obijiaku          771    France    Male   39
# 9996       9997    15569892  Johnstone          516    France    Male   35
# 9997       9998    15584532        Liu          709    France  Female   36
# 9998       9999    15682355  Sabbatini          772   Germany    Male   42
# 9999      10000    15628319     Walker          792    France  Female   28
#
# ...

# %%
print(banking.isnull().sum())
# Out:
# RowNumber          0
# CustomerId         0
# Surname            0
# CreditScore        0
# Geography          0
# Gender             0
# Age                0
# Tenure             0
# Balance            0
# NumOfProducts      0
# HasCrCard          0
# IsActiveMember     0
# EstimatedSalary    0
# Exited             0
# dtype: int64

# %%
banking = banking.dropna()
banking.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0
# 2        113931.57       1
# 3         93826.63       0
# ...

# %%
banking.loc[(data['Exited'] != 0) & (data['Exited'] != 1)]
# Out:
# Empty DataFrame
# Columns: [RowNumber, CustomerId, Surname, CreditScore, Geography, Gender, Age, Tenure, Balance, NumOfProducts, HasCrCard, IsActiveMember, EstimatedSalary, Exited]
# Index: []

# %%
banking["Gender"] = banking["Gender"].astype('category')
banking["Geography"] = banking["Geography"].astype('category')
banking["Exited"] = banking["Exited"].astype('category')
banking.dtypes
# Out:
# RowNumber             int64
# CustomerId            int64
# Surname              object
# CreditScore           int64
# Geography          category
# Gender             category
# Age                   int64
# Tenure                int64
# Balance             float64
# NumOfProducts         int64
# HasCrCard             int64
# IsActiveMember        int64
# EstimatedSalary     float64
# Exited             category
# dtype: object

# %%
categorical_data = data.drop(['RowNumber', 'CustomerId', 'Surname','CreditScore','Age','Tenure','Balance','NumOfProducts','HasCrCard','IsActiveMember','EstimatedSalary'], axis=1)
categorical_data.head(100)
# Out:
#    Geography  Gender Exited
# 0     France  Female      1
# 1      Spain  Female      0
# 2     France  Female      1
# 3     France  Female      0
# 4      Spain  Female      0
# ..       ...     ...    ...
# 95     Spain    Male      0
# 96     Spain    Male      0
# 97   Germany    Male      0
# 98     Spain    Male      0
# 99    France    Male      0
#
# [100 rows x 3 columns]

# %%
categorical_data.dtypes
# Out:
# Geography    category
# Gender         object
# Exited       category
# dtype: object

# %%
categorical_data['Gender'].unique()
# Out:
# array(['Female', 'Male'], dtype=object)

# %%
categorical_data["Geography_cat"] = categorical_data["Geography"].cat.codes
categorical_data["Exited_cat"] = categorical_data["Exited"].cat.codes
categorical_data.head()
# Out:
#   Geography  Gender Exited  Geography_cat  Exited_cat
# 0    France  Female      1              0           1
# 1     Spain  Female      0              2           0
# 2    France  Female      1              0           1
# 3    France  Female      0              0           0
# 4     Spain  Female      0              2           0

# %%
# We'll use a Random Forest
from sklearn.ensemble import RandomForestClassifier
clf = RandomForestClassifier(n_estimators=80)

# %%
clf.get_params()
# Out:
# {'bootstrap': True,
#  'ccp_alpha': 0.0,
#  'class_weight': None,
#  'criterion': 'gini',
#  'max_depth': None,
#  'max_features': 'auto',
#  'max_leaf_nodes': None,
#  'max_samples': None,
#  'min_impurity_decrease': 0.0,
#  'min_samples_leaf': 1,
#  'min_samples_split': 2,
#  'min_weight_fraction_leaf': 0.0,
#  'n_estimators': 80,
#  'n_jobs': None,
#  'oob_score': False,
#  'random_state': None,
#  'verbose': 0,
#  'warm_start': False}

# %%
clf.fit(X_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_7284/2395142735.py in <module>
# ----> 1 clf.fit(X_train, y_train)
#
# NameError: name 'X_train' is not defined

# %%
banking.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary Exited
# 0        101348.88      1
# 1        112542.58      0
# 2        113931.57      1
# 3         93826.63      0
# ...

# %%
X = banking.drop("EstimatedSalary", axis=1)

y = banking["EstimatedSalary"]

# %%
X.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember Exited
# 0       2       0.00              1          1               1      1
# 1       1   83807.86              1          0               1      0
# 2       8  159660.80              3          1               0      1
# 3       1       0.00              2          0               0      0
# 4       2  125510.82              1          1               1      0

# %%
y.head()
# Out:
# 0    101348.88
# 1    112542.58
# 2    113931.57
# 3     93826.63
# 4     79084.10
# Name: EstimatedSalary, dtype: float64

# %%
y.value_counts()
# Out:
# 24924.92     2
# 101348.88    1
# 55313.44     1
# 72500.68     1
# 182692.80    1
#             ..
# 120893.07    1
# 188377.21    1
# 55902.93     1
# 4523.74      1
# 38190.78     1
# Name: EstimatedSalary, Length: 9999, dtype: int64

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=100, stratify=y)

X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_7284/2544440086.py in <module>
#       1 from sklearn.model_selection import train_test_split
#       2
# ----> 3 X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=100, stratify=y)
#       4
#       5 X_train.shape, X_test.shape, y_train.shape, y_test.shape
#
# ~\anaconda3\lib\site-packages\sklearn\model_selection\_split.py in train_test_split(test_size, train_size, random_state, shuffle, stratify, *arrays)
#    2439         cv = CVClass(test_size=n_test, train_size=n_train, random_state=random_state)
#    2440
# -> 2441         train, test = next(cv.split(X=arrays[0], y=stratify))
#    2442
#    2443     return list(
#
# ~\anaconda3\lib\site-packages\sklearn\model_selection\_split.py in split(self, X, y, groups)
#    1598         """
# ...
